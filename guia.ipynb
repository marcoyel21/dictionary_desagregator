# %%
import pandas as pd
import json
#Se importan paquetes necesarios
#Se importa la tabla
df= pd.read_csv("data.csv")
df
# Out:
#      idFolio        sdFechaIndiza nvcFolioReferencia  nvcFolioEvento  \
# 0     852915  2018-08-14 00:00:00            196C001           61116
# 1     852933  2018-08-14 00:00:00            431C001           61351
# 2     852951  2018-08-14 00:00:00           2105C001           63021
# 3     852994  2018-08-14 00:00:00           9277C001           73034
# 4     853037  2018-08-14 00:00:00            722C001           61642
# ..       ...                  ...                ...             ...
# 995  1103962  2021-06-21 00:00:00         297960C006          139764
# 996  1103964  2021-06-21 00:00:00         297959C003          140080
# 997  1104044  2021-06-21 00:00:00         297968C006          143561
# 998  1103965  2021-06-21 00:00:00         297957C005          139190
# 999  1103966  2021-06-21 00:00:00         297958C001          144280
#
#     nvcTipoMensaje nvcClaveCotizacion  \
# 0              NEW                SHY
# 1              NEW                ICE
# 2              NEW                PFF
# 3              NEW                PBR
# 4              NEW                TLT
# ..             ...                ...
# 995        Replace               ODET
# 996        Replace                CON
# 997        Replace                VTC
# 998        Replace                EVO
# 999            NEW               6098
#
#                                        nvcRazonSocial nvcSerie       nvcIsin  \
# 0                  ISHARES 1-3 YEAR TREASURY BOND ETF        *  US4642874576
# 1                     INTERCONTINENTAL EXCHANGE, INC.        *  US45866F1049
# 2                    ISHARES U.S. PREFERRED STOCK ETF        *  US4642886877
# 3                PETRÓLEO BRASILEIRO S.A. - PETROBRAS        N  US71654V4086
# 4                  ISHARES 20+ YEAR TREASURY BOND ETF        *  US4642874329
# ..                                                ...      ...           ...
# 995                               COMPAGNIE DE L'ODET        N  FR0000062234
# 996                                    CONTINENTAL AG        N  DE0005439004
# 997                 VANGUARD TOTAL CORPORATE BOND ETF        *  US92206C5739
# 998                                      EVOLUTION AB        N  SE0012673267
# 999  COUNTRY GARDEN SERVICES HOLDINGS COMPANY LIMITED        N  KYG2453A1085
#
#           nvcMercadoPrincipal  ... nvcCompleto nvcConfirmado  \
# 0                      NASDAQ  ...  INCOMPLETE   UNCONFIRMED
# 1                  NUEVA YORK  ...    COMPLETE     CONFIRMED
# 2                      NASDAQ  ...  INCOMPLETE   UNCONFIRMED
# 3                  NUEVA YORK  ...    COMPLETE     CONFIRMED
# 4                      NASDAQ  ...  INCOMPLETE   UNCONFIRMED
# ..                        ...  ...         ...           ...
# 995            EURONEXT PARIS  ...    COMPLETE     CONFIRMED
# 996                     XETRA  ...  INCOMPLETE   UNCONFIRMED
# 997                    NASDAQ  ...    COMPLETE     CONFIRMED
# 998          NASDAQ STOCKHOLM  ...    COMPLETE     CONFIRMED
# 999  HONG KONG STOCK EXCHANGE  ...    COMPLETE     CONFIRMED
#
#                dtFechaExdate          dtFechaRegistro  \
# 0    2018-09-04 00:00:00.000  2018-09-05 00:00:00.000
# 1    2018-09-12 00:00:00.000  2018-09-13 00:00:00.000
# 2    2018-09-04 00:00:00.000  2018-09-05 00:00:00.000
# 3    2018-08-14 00:00:00.000  2018-08-15 00:00:00.000
# 4    2018-10-01 00:00:00.000  2018-10-02 00:00:00.000
# ..                       ...                      ...
# 995                      NaN                      NaN
# 996                      NaN                      NaN
# 997  2021-06-01 00:00:00.000  2021-06-02 00:00:00.000
# 998                      NaN                      NaN
# 999  2021-06-02 00:00:00.000  2021-06-03 00:00:00.000
#
#               dtFechaEfectos dtFechaPago dtDueBillOfDate  \
# 0                        NaN         NaN             NaN
# 1                        NaN         NaN             NaN
# 2                        NaN         NaN             NaN
# 3                        NaN         NaN             NaN
# 4                        NaN         NaN             NaN
# ..                       ...         ...             ...
# 995  2021-05-28 00:00:00.000         NaN             NaN
# 996                      NaN         NaN             NaN
# 997                      NaN         NaN             NaN
# 998  2021-05-19 00:00:00.000         NaN             NaN
# 999                      NaN         NaN             NaN
#
#                                         nvcTipoEventos  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995  [ {       "qualifierDescription" : "Change Typ...
# 996                                                NaN
# 997                                                NaN
# 998  [ {       "qualifierDescription" : "Change Typ...
# 999                                                NaN
#
#                                            nvcOpciones  \
# 0    [ {       "numero" : 1,       "tipo" : "Cash",...
# 1    [ {       "numero" : 1,       "tipo" : "Cash",...
# 2    [ {       "numero" : 1,       "tipo" : "Cash",...
# 3    [ {       "numero" : 1,       "tipo" : "Cash",...
# 4    [ {       "numero" : 1,       "tipo" : "Cash",...
# ..                                                 ...
# 995                                                NaN
# 996  [ {       "numero" : 1,       "tipo" : "Securi...
# 997  [ {       "numero" : 1,       "tipo" : "Cash",...
# 998                                                NaN
# 999  [ {       "numero" : 1,       "tipo" : "Cash",...
#
#                                               nvcNotas
# 0                        {       "addtlTxt" : ""     }
# 1                        {       "addtlTxt" : ""     }
# 2                        {       "addtlTxt" : ""     }
# 3                        {       "addtlTxt" : ""     }
# 4                        {       "addtlTxt" : ""     }
# ..                                                 ...
# 995  {       "addtlTxt" : "(27\/05\/2021)\r\n\r\nOl...
# 996  {         "addtlInf" : "Holders of Continental...
# 997  {       "addtlTxt" : "The U.S. source income r...
# 998  {       "addtlTxt" : "(27\/05\/2021)\r\n\r\nNe...
# 999  {         "addtlInf" : "Holders will receive d...
#
# [1000 rows x 22 columns]

# %%
#Ahora veamos como se desagrega la columna nvcOpciones
df["nvcOpciones"]
# Out:
# 0      [ {       "numero" : 1,       "tipo" : "Cash",...
# 1      [ {       "numero" : 1,       "tipo" : "Cash",...
# 2      [ {       "numero" : 1,       "tipo" : "Cash",...
# 3      [ {       "numero" : 1,       "tipo" : "Cash",...
# 4      [ {       "numero" : 1,       "tipo" : "Cash",...
#                              ...
# 995                                                  NaN
# 996    [ {       "numero" : 1,       "tipo" : "Securi...
# 997    [ {       "numero" : 1,       "tipo" : "Cash",...
# 998                                                  NaN
# 999    [ {       "numero" : 1,       "tipo" : "Cash",...
# Name: nvcOpciones, Length: 1000, dtype: object

# %%
# Cuando le damos formato json-diccionario podemos meternos a explorar


json.loads(df["nvcOpciones"][i])[0]#<---nos metemos al primer diccionario anidado
# Out:
# {'numero': 1,
#  'tipo': 'Cash',
#  'default': 'true',
#  'transacciones': [{'transaccion': 'Cash Movement',
#    'fechaPago': '30/08/2021',
#    'creditoDebito': 'Credit',
#    'importeBruto': {'amount': 0.2187,
#     'currency': 'CNY',
#     'rateType': 'IncomePortion'},
#    'importeNeto': {'amount': 0.2187,
#     'currency': 'CNY',
#     'rateType': 'IncomePortion'}}],
#  'notas': {'addtlInf': 'Holders will receive dividend in\r\n HKD.'}}

# %%
#nos metemos al primer diccionario anidado, luego al diccionario anidado transacciones, luego al primero dentro de transacciones.
json.loads(df["nvcOpciones"][i])[0]["transacciones"][0]
# Out:
# {'transaccion': 'Cash Movement',
#  'fechaPago': '30/08/2021',
#  'creditoDebito': 'Credit',
#  'importeBruto': {'amount': 0.2187,
#   'currency': 'CNY',
#   'rateType': 'IncomePortion'},
#  'importeNeto': {'amount': 0.2187,
#   'currency': 'CNY',
#   'rateType': 'IncomePortion'}}

# %%
#Ahora podemos crear un for loop para extraer la info que nos importa
#Se crea una tabla vacia para ir vaciando la info
table = pd.DataFrame(columns = ['dict'])
for i in range(len(df)):
#Si el diccionario anidado "transacciones" existe entonces extrae la info
    try:
        temp = pd.DataFrame([[json.loads(df["nvcOpciones"][i])[0]["transacciones"][0]]], columns = ['dict'])
        table = pd.concat([table, temp])
        
#Si no existe entonces pone un diccionario vacio
    except:
        temp = pd.DataFrame([['{}']], columns = ['dict'])
        table = pd.concat([table, temp])

table.reset_index(inplace=True)
table=table.drop(columns=['index'])

# %%
#table contiene el primer subdiccionario del diccionario anidado de "transacciones"
table
# Out:
#                                                   dict
# 0    {'transaccion': 'Cash Movement', 'fechaPago': ...
# 1    {'transaccion': 'Cash Movement', 'fechaPago': ...
# 2    {'transaccion': 'Cash Movement', 'fechaPago': ...
# 3    {'transaccion': 'Cash Movement', 'fechaPago': ...
# 4    {'transaccion': 'Cash Movement', 'fechaPago': ...
# ..                                                 ...
# 995                                                 {}
# 996  {'transaccion': 'Securities Movement', 'credit...
# 997  {'transaccion': 'Cash Movement', 'fechaPago': ...
# 998                                                 {}
# 999  {'transaccion': 'Cash Movement', 'fechaPago': ...
#
# [1000 rows x 1 columns]

# %%
# Finalmente expando el diccionario en formato tabla (con nas donde no hay info)
# Esta tabla solo contiene las nuevas columnas
df_new_columns = pd.json_normalize(table['dict'])
df_new_columns
# Out:
#              transaccion   fechaPago creditoDebito  importeBruto.amount  \
# 0          Cash Movement  10/09/2018        Credit                  NaN
# 1          Cash Movement  28/09/2018        Credit             0.240000
# 2          Cash Movement  10/09/2018        Credit                  NaN
# 3          Cash Movement  04/09/2018        Credit             0.026963
# 4          Cash Movement  05/10/2018        Credit                  NaN
# ..                   ...         ...           ...                  ...
# 995                  NaN         NaN           NaN                  NaN
# 996  Securities Movement         NaN        Credit                  NaN
# 997        Cash Movement  04/06/2021        Credit             0.180000
# 998                  NaN         NaN           NaN                  NaN
# 999        Cash Movement  30/08/2021        Credit             0.218700
#
#     importeBruto.currency importeBruto.rateType  importeNeto.amount  \
# 0                     NaN                   NaN                 NaN
# 1                     USD         IncomePortion                 NaN
# 2                     NaN                   NaN                 NaN
# 3                     USD        TaxablePortion            0.020169
# 4                     NaN                   NaN                 NaN
# ..                    ...                   ...                 ...
# 995                   NaN                   NaN                 NaN
# 996                   NaN                   NaN                 NaN
# 997                   USD         IncomePortion            0.180000
# 998                   NaN                   NaN                 NaN
# 999                   CNY         IncomePortion            0.218700
#
#     importeNeto.currency importeNeto.rateType retencion.percent  ...  \
# 0                    NaN                  NaN               NaN  ...
# 1                    NaN                  NaN               NaN  ...
# 2                    NaN                  NaN               NaN  ...
# 3                    USD       TaxablePortion              15.0  ...
# 4                    NaN                  NaN               NaN  ...
# ..                   ...                  ...               ...  ...
# 995                  NaN                  NaN               NaN  ...
# 996                  NaN                  NaN               NaN  ...
# 997                  USD        IncomePortion               NaN  ...
# 998                  NaN                  NaN               NaN  ...
# 999                  CNY        IncomePortion               NaN  ...
#
#     efectivoRecibir.currency efectivoRecibir.amount periodoCotizacionValoresR  \
# 0                        NaN                    NaN                       NaN
# 1                        NaN                    NaN                       NaN
# 2                        NaN                    NaN                       NaN
# 3                        NaN                    NaN                       NaN
# 4                        NaN                    NaN                       NaN
# ..                       ...                    ...                       ...
# 995                      NaN                    NaN                       NaN
# 996                      NaN                    NaN                       NaN
# 997                      NaN                    NaN                       NaN
# 998                      NaN                    NaN                       NaN
# 999                      NaN                    NaN                       NaN
#
#                   ratio.qualifierDescription ratio.quantity1 ratio.quantity2  \
# 0                                        NaN             NaN             NaN
# 1                                        NaN             NaN             NaN
# 2                                        NaN             NaN             NaN
# 3                                        NaN             NaN             NaN
# 4                                        NaN             NaN             NaN
# ..                                       ...             ...             ...
# 995                                      NaN             NaN             NaN
# 996  AdditionalQuantityForExistingSecurities             1.0             5.0
# 997                                      NaN             NaN             NaN
# 998                                      NaN             NaN             NaN
# 999                                      NaN             NaN             NaN
#
#     valoresRecibir.indicatorDescription valoresRecibir.isin  \
# 0                                   NaN                 NaN
# 1                                   NaN                 NaN
# 2                                   NaN                 NaN
# 3                                   NaN                 NaN
# 4                                   NaN                 NaN
# ..                                  ...                 ...
# 995                                 NaN                 NaN
# 996                                 NaN                 NaN
# 997                                 NaN                 NaN
# 998                                 NaN                 NaN
# 999                                 NaN                 NaN
#
#     valoresRecibir.descripcion disposicionFracciones
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# 2                          NaN                   NaN
# 3                          NaN                   NaN
# 4                          NaN                   NaN
# ..                         ...                   ...
# 995                        NaN                   NaN
# 996                       UKWN                   NaN
# 997                        NaN                   NaN
# 998                        NaN                   NaN
# 999                        NaN                   NaN
#
# [1000 rows x 23 columns]

# %%
# Pego ambas tablas (las nuevas columnas y las viejas)
df_complete = pd.concat([df, df_new_columns], axis=1)
df_complete


# Guardo en csv
#df_new_columns.to_csv("data2.csv")
#df_complete.to_csv("data2.csv")
# Out:
#      idFolio        sdFechaIndiza nvcFolioReferencia  nvcFolioEvento  \
# 0     852915  2018-08-14 00:00:00            196C001           61116
# 1     852933  2018-08-14 00:00:00            431C001           61351
# 2     852951  2018-08-14 00:00:00           2105C001           63021
# 3     852994  2018-08-14 00:00:00           9277C001           73034
# 4     853037  2018-08-14 00:00:00            722C001           61642
# ..       ...                  ...                ...             ...
# 995  1103962  2021-06-21 00:00:00         297960C006          139764
# 996  1103964  2021-06-21 00:00:00         297959C003          140080
# 997  1104044  2021-06-21 00:00:00         297968C006          143561
# 998  1103965  2021-06-21 00:00:00         297957C005          139190
# 999  1103966  2021-06-21 00:00:00         297958C001          144280
#
#     nvcTipoMensaje nvcClaveCotizacion  \
# 0              NEW                SHY
# 1              NEW                ICE
# 2              NEW                PFF
# 3              NEW                PBR
# 4              NEW                TLT
# ..             ...                ...
# 995        Replace               ODET
# 996        Replace                CON
# 997        Replace                VTC
# 998        Replace                EVO
# 999            NEW               6098
#
#                                        nvcRazonSocial nvcSerie       nvcIsin  \
# 0                  ISHARES 1-3 YEAR TREASURY BOND ETF        *  US4642874576
# 1                     INTERCONTINENTAL EXCHANGE, INC.        *  US45866F1049
# 2                    ISHARES U.S. PREFERRED STOCK ETF        *  US4642886877
# 3                PETRÓLEO BRASILEIRO S.A. - PETROBRAS        N  US71654V4086
# 4                  ISHARES 20+ YEAR TREASURY BOND ETF        *  US4642874329
# ..                                                ...      ...           ...
# 995                               COMPAGNIE DE L'ODET        N  FR0000062234
# 996                                    CONTINENTAL AG        N  DE0005439004
# 997                 VANGUARD TOTAL CORPORATE BOND ETF        *  US92206C5739
# 998                                      EVOLUTION AB        N  SE0012673267
# 999  COUNTRY GARDEN SERVICES HOLDINGS COMPANY LIMITED        N  KYG2453A1085
#
#           nvcMercadoPrincipal  ... efectivoRecibir.currency  \
# 0                      NASDAQ  ...                      NaN
# 1                  NUEVA YORK  ...                      NaN
# 2                      NASDAQ  ...                      NaN
# 3                  NUEVA YORK  ...                      NaN
# 4                      NASDAQ  ...                      NaN
# ..                        ...  ...                      ...
# 995            EURONEXT PARIS  ...                      NaN
# 996                     XETRA  ...                      NaN
# 997                    NASDAQ  ...                      NaN
# 998          NASDAQ STOCKHOLM  ...                      NaN
# 999  HONG KONG STOCK EXCHANGE  ...                      NaN
#
#     efectivoRecibir.amount periodoCotizacionValoresR  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
# ..                     ...                       ...
# 995                    NaN                       NaN
# 996                    NaN                       NaN
# 997                    NaN                       NaN
# 998                    NaN                       NaN
# 999                    NaN                       NaN
#
#                   ratio.qualifierDescription ratio.quantity1 ratio.quantity2  \
# 0                                        NaN             NaN             NaN
# 1                                        NaN             NaN             NaN
# 2                                        NaN             NaN             NaN
# 3                                        NaN             NaN             NaN
# 4                                        NaN             NaN             NaN
# ..                                       ...             ...             ...
# 995                                      NaN             NaN             NaN
# 996  AdditionalQuantityForExistingSecurities             1.0             5.0
# 997                                      NaN             NaN             NaN
# 998                                      NaN             NaN             NaN
# 999                                      NaN             NaN             NaN
#
#     valoresRecibir.indicatorDescription  valoresRecibir.isin  \
# 0                                   NaN                  NaN
# 1                                   NaN                  NaN
# 2                                   NaN                  NaN
# 3                                   NaN                  NaN
# 4                                   NaN                  NaN
# ..                                  ...                  ...
# 995                                 NaN                  NaN
# 996                                 NaN                  NaN
# 997                                 NaN                  NaN
# 998                                 NaN                  NaN
# 999                                 NaN                  NaN
#
#      valoresRecibir.descripcion disposicionFracciones
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# ..                          ...                   ...
# 995                         NaN                   NaN
# 996                        UKWN                   NaN
# 997                         NaN                   NaN
# 998                         NaN                   NaN
# 999                         NaN                   NaN
#
# [1000 rows x 45 columns]
